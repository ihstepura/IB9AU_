# %% [markdown]
# <a href="https://colab.research.google.com/github/ihstepura/IB9AU_/blob/main/task_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Answer: Executive Summary
#
# Overall, Coinbase’s strategy is showing meaningful progress, but it is not yet fully insulated from market cycles. On the Q3 2024 earnings call, transaction revenue was down by 27% QoQ due to crypto volatility. The revenue mix was more balanced in prior cycles because subscription and services nearly matched the transaction revenue, meaning that the business was not predominantly dependent on trading fees. While trading fees remained a significant driver and fell sharply in weak markets, Coinbase’s non-trading revenue streams showed increasing stability and scale. The strategy is directionally working, but not yet fully decoupled from crypto market conditions as of Q3 2024.

# %% [markdown]
# Required Task 7
#
# Coinbase earnings call transcript: https://www.fool.com/earnings/call-transcripts/2024/10/30/coinbase-global-coin-q3-2024-earnings-call-transcr/
#
# The Base Question: "Is Coinbase's strategy to reduce reliance on volatile trading fees actually working as of Q3 2024?"
#
# Use four different prompting techniques to answer the question. Use an LLM as a judge to rate the results from different prompts. Based on the "Judge's" feedback, write a final 200-word Executive Summary answering the Base Question.
#
# Prompt 1: https://chatgpt.com/share/69973e0f-d500-8004-8e41-6cc4f992c449
#
# ## Input 1
#
# Gain access to Coinbase earnings call transcript: https://www.fool.com/earnings/call-transcripts/2024/10/30/coinbase-global-coin-q3-2024-earnings-call-transcr/
#
# Answer the question: Is Coinbase's strategy to reduce reliance on volatile trading fees actually working as of Q3 2024?
#
# ## Output 1
#
# Yes — according to Coinbase’s Q3 2024 earnings call and shareholder letter, the company’s strategy to reduce reliance on volatile trading fees and shift toward more predictable subscription-and-services revenue was making tangible progress as of Q3 2024, but it wasn’t yet fully “proven” as a complete replacement for those volatile trading fees. Here’s what the call indicated:

# %% [markdown]
# 📉 Trading Fee Volatility Still Evident
#
# Coinbase acknowledged that transaction (trading) revenue declined significantly in Q3 2024. Total transaction revenue was down about 27% quarter-over-quarter, largely due to lower market volatility and reduced average asset prices — conditions that directly impact trading fee income.

# %% [markdown]
# 📈 Progress on Diversification
#
# The company highlighted that it has shifted more of its revenue mix toward subscription and services, which includes things like staking, custody, Prime brokerage services, and other non-transaction income sources. In 2024, subscription and services revenue was on pace to exceed $2 billion, up from about $1.4 billion in 2023 — a sign of meaningful growth in those less volatile parts of the business.
#
# Coinbase’s CFO explicitly said that long-term revenue diversification efforts are paying off and that subscription/services revenues were growing faster than trading revenues overall, even if still impacted by market conditions within that quarter.

# %% [markdown]
# 📊 Headwinds Still Present
#
# Despite the progress, the company also noted headwinds in subscription and services revenue tied to lower crypto prices and macro pressures — which shows these newer revenue streams were not yet fully insulated from broader market effects.

# %% [markdown]
# ### Bottom Line

# %% [markdown]
# ✔ Yes — Coinbase has made meaningful strides in reducing reliance on volatile trading fees, as evidenced by growth in its subscription and services income.

# %% [markdown]
# ❗ But — trading fees still declined sharply in Q3 2024 due to market conditions, and diversifying revenue has not yet fully insulated overall results from crypto market swings.

# %% [markdown]
# So, as of Q3 2024, the strategy is working in part and showing progress, but it hasn’t completely replaced or fully stabilized revenue away from trading fees yet.

# %% [markdown]
# Prompt 2: https://chatgpt.com/share/69973e28-6dac-8004-850d-8ff283975191
#
# Input 2: Using the Coinbase Q3 2024 earnings call transcript, explain step by step what the trends in trading fees, subscription and services revenues, and other revenue lines were. Then conclude: Is Coinbase successfully reducing reliance on volatile trading fees as of Q3 2024? Include supporting numbers and trends.  https://www.fool.com/earnings/call-transcripts/2024/10/30/coinbase-global-coin-q3-2024-earnings-call-transcr/

# %% [markdown]
# Output 2: Below is a step-by-step read-through of the revenue trends described on Coinbase’s Q3 2024 earnings call transcript, focusing on (1) trading fees (transaction revenue), (2) subscription & services revenue, and (3) “other” revenue lines, and then a conclusion on whether Coinbase is reducing reliance on volatile trading fees as of Q3 2024.

# %% [markdown]
# ### 1) Trading fees / Transaction revenue: what happened and why (step by step)

# %% [markdown]
# ### Step 1 — Trading activity cooled vs Q2
#
# Coinbase said total trading volume was $185B, down 18% quarter-over-quarter (QoQ), driven by lower crypto volatility and lower average asset prices in Q3.

# %% [markdown]
# ### Step 2 — Transaction revenue fell faster than volume
#
# Transaction revenue was $573M, down 27% QoQ.
#
# Management explicitly flagged that volume and transaction revenue didn’t move one-for-one, and then explained the drivers.

# %% [markdown]
# ### Step 3 — Mix shift toward stablecoin pairs reduced fee yield
#
# Coinbase highlighted that consumer stablecoin-pair trading volume grew significantly QoQ, partly due to a product update making stablecoin trading easier for advanced traders.
#
# But they also said they generate “little-to-no fees” on stablecoin pair trades—so that mix shift pressures trading fee revenue, even if volume holds up.

# %% [markdown]
# ### Step 4 — “Non-trading consumer transaction revenue” declined
#
# They noted a decrease in non-trading consumer transaction revenue (they described this bucket as including DEX-related revenue and minor fees).

# %% [markdown]
# ### Step 5 — Institutional spot weaker, but diversification efforts showing early signs
#
# Coinbase said institutional spot revenue declined QoQ, while prime broker and derivatives outperformed relatively. Derivatives were “not yet material,” but described as an early positive sign for diversification.

# %% [markdown]
# Net of all this: Q3 was a quarter where market conditions + fee mix pushed transaction revenue down sharply.

# %% [markdown]
# ### 2) Subscription & Services revenue: what happened and why (step by step)

# %% [markdown]
# ### Step 1 — Subscription & services dipped modestly QoQ
#
# Subscription and services revenue was $556M, down 7% QoQ.

# %% [markdown]
# ### Step 2 — Underlying usage grew in key components (but pricing hurt)
#
# Coinbase said they grew “native units” in staking and custody (i.e., underlying activity/amounts on-platform increased).
#
# However, this was offset by lower average crypto asset prices, which mechanically reduces revenues tied to asset values.

# %% [markdown]
# ### Step 3 — Stablecoin revenue increased despite lower rates
#
# Coinbase said Q3 stablecoin revenue grew 3%, because USDC market cap growth and on-platform USDC balances outweighed the headwind from lower interest rates.

# %% [markdown]
# ### Step 4 — Coinbase One subscription base hit new highs
#
# They stated Coinbase One paid subscribers continued to grow and hit new all-time highs in Q3 (important as a recurring revenue driver).

# %% [markdown]
# ### Step 5 — Management emphasized the multi-year diversification trend
#
# CEO Brian Armstrong reiterated the strategic shift away from volatile transaction fees toward subscription & services, and said Coinbase is on pace to surpass $2B in subscription & services revenue in 2024, up from $1.4B in 2023.
#
# CFO echoed that subscription & services is on pace to exceed $2B this year.

# %% [markdown]
# Net of all this: Even with Q3’s softer market conditions, subscription & services held up far better than transaction revenue (-7% vs -27% QoQ).

# %% [markdown]
# ### 3) “Other” revenue lines: what the call implies (step by step)

# %% [markdown]
# ### Step 1 — Total revenue anchor
#
# Coinbase reported Q3 total revenue of $1.2B.

# %% [markdown]
# ### Step 2 — What’s explicitly broken out on the call
#
# ### The call explicitly gives
#
# Transaction revenue: $573M
#
# Subscription & services: $556M

# %% [markdown]
# ### Step 3 — Implied “other revenue” (residual)
#
# The transcript does not explicitly detail the remaining revenue line(s) by name in the prepared remarks shown here.
#
# ### But numerically, the implied remainder is approximately
#
# $1.2B total − $573M transaction − $556M subscription/services ≈ $71M (rounding likely).

# %% [markdown]
# So “other revenue” appears small relative to the two major buckets in Q3 2024, at least as presented in this transcript.

# %% [markdown]
# Conclusion: Is Coinbase reducing reliance on volatile trading fees as of Q3 2024?

# %% [markdown]
# Yes—there’s clear evidence of progress in reducing reliance, but transaction fees are still a major driver.

# %% [markdown]
# Supporting numbers and trends from the call
#
# Revenue mix is much more balanced in Q3 2024 than a “pure trading fee” business

# %% [markdown]
# Transaction revenue: $573M
#
# Subscription & services: $556M
#
# These are nearly equal in size, meaning Coinbase’s revenue base is not dominated by trading fees in this quarter.

# %% [markdown]
# When trading softened, subscription & services was far more stable

# %% [markdown]
# Transaction revenue: down 27% QoQ
#
# Subscription & services: down only 7% QoQ
#
# That relative resilience is exactly what “de-risking from trading volatility” looks like in practice.

# %% [markdown]
# Recurring/utility-driven lines are growing underneath

# %% [markdown]
# Stablecoin revenue grew 3% QoQ, driven by USDC market cap and on-platform balances (despite lower rates).
#
# Coinbase One subscribers hit all-time highs.
#
# Management expects subscription & services to exceed $2B in 2024 vs $1.4B in 2023 (a meaningful step-up).

# %% [markdown]
# The caveat

# %% [markdown]
# Even with diversification progress, transaction revenue was still slightly larger than subscription & services in Q3 ($573M vs $556M), so Coinbase is not “done” becoming less trading-dependent—it’s closer to a 50/50 model in this snapshot quarter.

# %% [markdown]
# If you want, I can convert this into a one-slide “revenue mix & diversification verdict” (bullet-ready) for a case discussion.

# %% [markdown]
# Prompt 3: https://chatgpt.com/share/69973e3a-ca98-8004-b773-3fd224d3a7a0
#
# Input 3: You are a Wall Street equity research analyst covering Coinbase. Read the Q3 2024 Coinbase earnings call transcript. Provide an executive summary assessing whether Coinbase’s strategy to reduce reliance on volatile trading fees is working. Focus on portfolio diversification, revenue mix, fee trends and recurring revenue growth with clear data references. https://www.fool.com/earnings/call-transcripts/2024/10/30/coinbase-global-coin-q3-2024-earnings-call-transcr/

# %% [markdown]
# Output 3: Executive summary — Is Coinbase’s “less trading-fee reliant” strategy working (Q3’24 call)?

# %% [markdown]
# Overall read: yes, the strategy is working directionally, but it’s not yet “de-coupled” from crypto macro. In Q3’24, Coinbase’s non-trading lines were large enough to partially offset weaker spot trading conditions, and management framed 2024 as a step-change year for Subscription & Services (S&S).

# %% [markdown]
# ### 1) Revenue mix is far more balanced than a pure exchange model
#
# Total revenue: $1.2B in Q3.
#
# Transaction revenue: $573M (down 27% QoQ) on $185B trading volume (down 18% QoQ).
#
# Subscription & Services revenue: $556M (down 7% QoQ).

# %% [markdown]
# Implication: Trading fees are no longer “the whole story.” In Q3, transaction revenue ($573M) and S&S ($556M) were near parity, which is exactly what “de-risking trading” looks like in the income statement during a softer tape.

# %% [markdown]
# ### 2) Fee trends: mix shift (stablecoins + advanced) pressured transaction monetization

# %% [markdown]
# Management highlighted a notable mix shift: consumer stablecoin pair trading volume grew significantly QoQ, driven in part by a product update for advanced traders.
#
# Coinbase noted it generates “little-to-no fees” on stablecoin pair trades.
#
# They also flagged that excluding stablecoin impact, the mix of advanced volume was slightly higher in Q3 vs Q2 (advanced tends to have lower fee rates than simple retail).

# %% [markdown]
# So, while volumes fell 18% QoQ, transaction revenue fell 27% QoQ—consistent with take-rate pressure from mix, not just lower activity.

# %% [markdown]
# ### 3) “Recurring”/less-volatile revenue is growing, but still macro-linked

# %% [markdown]
# ### Coinbase’s core diversification engine in 2024 is S&S
#
# Management said Coinbase is “on pace to surpass $2B in subscription and services revenue in 2024,” up from $1.4B in 2023.

# %% [markdown]
# ### Within S&S, the call emphasized three recurring pillars
#
# Stablecoin monetization (USDC economics): Q3 stablecoin revenue grew 3%, with USDC market cap and on-platform USDC balances offsetting lower rates.
#
# Staking + custody: Coinbase said it grew native units in staking and custody, but revenues were offset by lower average crypto prices in the quarter—important because it shows “recurring” is still partially AUM/price sensitive.
#
# Coinbase One: paid subscribers hit new all-time highs (supports a more subscription-like model).

# %% [markdown]
# Bottom line: S&S is increasingly “recurring,” but it’s not immune—rates and asset prices still matter (management explicitly called out headwinds from ETH price and lower rates looking into Q4).

# %% [markdown]
# ### 4) Portfolio diversification beyond spot: early, but visible

# %% [markdown]
# The call points to a broader product portfolio intended to reduce spot-fee cyclicality:
#
# Derivatives/prime broker: management cited “relative outperformance” in prime broker and derivatives, with derivatives revenue growth “not yet material” but beginning to contribute as diversification priority.
#
# Base (L2), Smart Wallet, cbBTC: still early monetization; Base fees intentionally kept low (median tx fee < $0.01) to scale, with Q/Q transaction growth cited.

# %% [markdown]
# Conclusion (investment-style)

# %% [markdown]
# Yes—Coinbase is demonstrably less reliant on volatile trading fees than in prior cycles. The most concrete proof in Q3’24 is that S&S revenue ($556M) nearly matched transaction revenue ($573M) even as trading conditions softened, and management guided to >$2B S&S in 2024 vs $1.4B in 2023.

# %% [markdown]
# However, “reduced reliance” does not equal “low volatility”: key S&S drivers (USDC economics, staking/custody) remain sensitive to interest rates and crypto asset prices, and transaction monetization can be pressured by stablecoin/advanced mix.

# %% [markdown]
# If you want, I can turn this into a 1-page ER-style note with: (1) a revenue bridge (Q2→Q3), (2) implied take-rate math, and (3) a quick KPI dashboard you can reuse for Q4/Q1 comparisons.

# %% [markdown]
# Prompt 4: https://chatgpt.com/share/69973e5e-0064-8004-b23e-224bcbd837f5
#
# Input 4: Based on the Coinbase Q3 2024 earnings call transcript:

# %% [markdown]
# ### 1) Total trading fee trends this quarter
#
# ### 2) Growth (or decline) of subscription and services revenue
#
# ### 3) Any commentary from management on fee diversification
#
# ### 4) Final evaluation: Yes or No — is the strategy working?
#
# Provide bullet points and cite the transcript where appropriate. https://www.fool.com/earnings/call-transcripts/2024/10/30/coinbase-global-coin-q3-2024-earnings-call-transcr/

# %% [markdown]
# Output 4: Here’s a focused summary of key points from the Coinbase Q3 2024 earnings call transcript on the topics you asked about — with direct citations from the transcript where available.

# %% [markdown]
# ### 1) Total Trading Fee Trends This Quarter
#
# Trading volume declined significantly — total trading volume in Q3 was $185 billion, down 18% quarter-over-quarter.
#
# Transaction (trading) revenue fell more sharply — total transaction revenue was $573 million, down 27% quarter-over-quarter, largely due to lower crypto market volatility and a shift toward stablecoin pair trades that generate little-to-no fees.
#
# Management noted stablecoin trading grew, but the company earns little-to-no fees on stablecoin pair transactions, so the trend reduced overall fee revenue.

# %% [markdown]
# Takeaway: Trading fees declined materially vs. Q2 2024 due to lower volume and a shift toward low-fee trades.

# %% [markdown]
# ### 2) Growth (or Decline) of Subscription & Services Revenue
#
# Subscription and services revenue was $556 million in Q3, which was down ~7% quarter-over-quarter.
#
# The decline was attributed to lower average crypto asset prices impacting revenue from products like staking and custody, even though underlying units (e.g., subscribers) grew.
#
# Despite the quarterly decline, management emphasized that the revenue category remains central to its diversification strategy and is on track to surpass $2 billion in subscription and services revenue for full-year 2024.

# %% [markdown]
# Takeaway: Subscription & services revenue declined this quarter, but full-year growth remains a key focus.

# %% [markdown]
# ### 3) Management Commentary on Fee Diversification
#
# Coinbase reiterated that diversifying away from volatile transaction fees toward more predictable subscription & services revenue is a core priority.
#
# CEO Brian Armstrong highlighted that subscription & services revenue has grown significantly over the years, helping stabilise overall revenue — e.g., on pace for over $2 billion in 2024 versus $1.4 billion in 2023.
#
# CFO Alesia Haas reinforced that revenue diversification is a top financial goal, with continued product adoption and growth in native units (like Coinbase One subscribers) seen as crucial.
#
# They also noted headwinds for Q4 subscription growth (like a recent Ether price decline and lower interest rates) but remained committed to growing non-trading revenue.

# %% [markdown]
# Takeaway: Management explicitly stated the diversification effort away from trading fees to subscription and services is ongoing and strategic.

# %% [markdown]
# ### 4) Final Evaluation: Is the Strategy Working?

# %% [markdown]
# Yes — but with caveats.

# %% [markdown]
# ### Reasons supporting “Yes”
#
# Diversification is progressing: Management highlighted that subscription & services revenue has grown materially on a full-year basis (on pace for over $2 billion).
#
# Stable EBITDA and profitability across market environments reflect operational resilience beyond trading fees.
#
# Growth in subscribers and stablecoin adoption signals traction in non-trading segments.

# %% [markdown]
# ### Reasons for caution
#
# Subscription & services revenue fell quarter-over-quarter, partly due to market headwinds.
#
# Trading fees still remain a meaningful revenue source, and declines here materially impact total revenue.

# %% [markdown]
# ### Overall Judgement
#
# 🔹 Yes — the fee-diversification strategy is working structurally but not perfectly in every quarter. Coinbase is progressively reducing reliance on volatile trading fees by growing subscription & services revenue, even if short-term results can still be impacted by market conditions.

# %% [markdown]
# Let me know if you want a side-by-side table comparing Q2 vs. Q3 metrics or a quick chart summarizing the revenue mix trends!
